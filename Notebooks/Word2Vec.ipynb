# %%
print("Antas")
# Out:
# Antas

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("saurabhbadole/game-of-thrones-book-dataset")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (0.4.2).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/saurabhbadole/game-of-thrones-book-dataset?dataset_version_number=1...
# 100%|██████████| 3.71M/3.71M [00:00<00:00, 135MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/saurabhbadole/game-of-thrones-book-dataset/versions/1

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.0)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 61.1 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import gensim
from gensim.models import Word2Vec

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os

# %%
import nltk
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# {"won't", 'have', 'ours', "they're", 'my', "hasn't", 'is', 'for', 'in', 'o', 'itself', 'the', 'yourself', 'few', 'i', 'aren', 'mustn', 'his', 'some', 'do', 'here', 'won', 'from', 'how', 'than', 'isn', "doesn't", 'or', 'then', 'by', 'nor', 'those', 'were', 'other', 'at', "you're", 'doing', 'be', "he'd", 'whom', 'against', "mightn't", 'over', "weren't", 'why', "we've", 'further', 'myself', 'which', 'above', 'd', 'had', 'does', 'own', 'so', "mustn't", 'on', 'of', 'each', 'only', 'am', 'needn', "haven't", 'did', "aren't", 'once', 'as', "i've", "i'll", 't', 'this', 'don', 'hadn', "she'll", 'been', "they'll", 'being', 'haven', 'we', 've', "shan't", 'him', 'ma', 'are', 'couldn', 'you', "don't", 'they', 'its', "we're", 'she', 'that', 'll', 'themselves', 'because', "he'll", 'below', 'through', 'yours', "they've", 'hers', 'down', 'himself', "that'll", "we'll", 'm', 'theirs', "it'd", "you'll", 'about', "we'd", 'now', 'where', 'he', 'no', 'between', 'both', 'off', 'who', "you'd", 'these', 'under', 'our', 'has', 'your', 'ourselves', 'too', 'if', 'such', 'when', 'her', "he's", 're', 'after', "should've", "didn't", 'not', "you've", 'should', 'very', 'during', 'me', 'shan', 'most', 'same', 'herself', 'mightn', 'until', 'wasn', 's', 'ain', 'to', 'it', "needn't", 'but', 'there', 'was', 'again', 'a', 'any', 'with', 'an', "i'd", "isn't", "wouldn't", "hadn't", "couldn't", "i'm", 'can', 'all', 'them', 'what', 'while', 'their', "it'll", "it's", "wasn't", 'weren', 'wouldn', "she's", 'yourselves', 'didn', 'hasn', 'and', 'just', 'out', 'will', 'y', 'doesn', 'before', 'up', "they'd", 'having', 'into', 'more', "she'd", 'shouldn', "shouldn't"}

# %%
documents = []

for filename in os.listdir(path):
  with open(os.path.join(path, filename), encoding="utf-8", errors="ignore") as f:
    text = f.read()
    sents_list = sent_tokenize(text)
    for sent in sents_list:
      documents.append(simple_preprocess(sent))

print(len(documents[98]))
# Out:
# 23

# %%
new_documents = []
for doc in documents:
  new_doc = [word for word in doc if word not in stop_words]
  new_documents.append(new_doc)

print(len(new_documents[98]))
# Out:
# 12

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=3
)

# %%
model.build_vocab(new_documents)

# %%
model.train(new_documents, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (4387334, 4596315)

# %%
#using functions of a Word2Vec model
model.wv.most_similar("places")
# Out:
# [('passages', 0.9550418853759766),
#  ('shoals', 0.9498198628425598),
#  ('villages', 0.9487659931182861),
#  ('seas', 0.9484611749649048),
#  ('roads', 0.9483909010887146),
#  ('mules', 0.9461223483085632),
#  ('mounts', 0.9449623823165894),
#  ('coasts', 0.9447057247161865),
#  ('towns', 0.9439898729324341),
#  ('shelter', 0.9428893327713013)]

# %%
#embeddings of the words
#by default size =100
model.wv["king"]
# Out:
# array([-0.76451856,  1.6349639 ,  0.04740463,  1.9022397 , -0.20987438,
#        -1.3510016 , -0.6712737 ,  2.5724387 ,  0.03993686, -1.8159069 ,
#         1.108573  , -1.9563769 ,  0.83470154,  0.36956638, -0.58336675,
#        -0.20546363,  1.9298584 , -2.3690968 , -0.21094918, -1.83217   ,
#        -0.9827389 ,  2.5314386 , -0.11144537, -2.8672233 ,  1.0808694 ,
#         0.55250245, -2.5225544 ,  1.1147064 , -1.1654085 , -0.25543815,
#         1.1488104 ,  1.3393288 ,  2.317545  ,  3.4668095 , -0.45995033,
#         0.6085969 ,  0.10410796,  0.74774075,  0.66591585,  0.77515525,
#         0.9511888 ,  0.8834849 ,  0.5585705 , -0.17863697, -0.25600758,
#         1.6961029 , -0.25668746, -0.9941372 ,  0.34077486,  0.37262043,
#         1.7161418 ,  0.24465564, -2.4242404 ,  1.7116151 ,  0.30459994,
#        -1.7377611 , -1.7654523 , -0.9601257 , -0.18136247,  0.57233113,
#         0.35930482,  1.632954  , -0.12640944, -1.3833792 , -2.3269114 ,
#        -0.00600235,  0.12971875,  0.76490384,  0.44194213, -1.4492729 ,
#         0.15768307, -0.2973035 , -0.05613467, -1.8788401 ,  0.9917546 ,
#        -0.08405087, -0.14797273, -0.30674306, -0.45070568,  0.10554207,
#        -0.07804429,  0.5861982 , -0.85145074,  1.6731218 , -0.16674341,
#         0.43981215, -1.6451161 , -0.76111895,  1.1724238 ,  0.34804568,
#         0.4081449 ,  2.0179706 , -0.46994898,  0.8887266 ,  2.0413818 ,
#         0.24058433,  0.64293337, -0.34777746,  0.31191045,  0.01214806],
#       dtype=float32)

# %%
mo = model.wv.get_normed_vectors()
print(mo.shape)
# Out:
# (14894, 100)

# %%
print(model.wv.similarity("king", "queen"))
# Out:
# 0.59219885
